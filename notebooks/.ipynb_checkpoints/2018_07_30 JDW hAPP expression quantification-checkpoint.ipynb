# %%
import os
import pandas as pd
import seaborn as sns
sns.set_context('poster')
sns.set_style('white')

import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42

import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as st

from allensdk.core.mouse_connectivity_cache import MouseConnectivityCache

# %%
path = r'/Users/jenniferwh/Dropbox (Allen Institute)/Mesoscale Connectome Papers in Progress/2018 Plaque/hAPP immunostaining'

# %%
dat = pd.read_csv(os.path.join(path, 'hippocampal APP quantification.csv'))

# %%
dat.head()
# Out:
#   Genotype APP Sex    SUBd     CA1     CA3      DG       P
# 0  APP/PS1   -   F  477200  456283  790589  287563  724120
# 1  APP/PS1   -   F  539422  466490  629405  306358  726202
# 2  APP/PS1   -   F  546485  511429  625106  346131  761662
# 3  APP/PS1   -   F  505672  466640  613286  351195  692502
# 4  APP/PS1   -   F  510717  454516  560597  324772  666527

# %%
dat['Genotype'].unique()
# Out:
# array(['APP/PS1', 'J20', 'Tg2576 (1)', 'Tg2576'], dtype=object)

# %%
dat.loc[dat['Genotype'] == 'Tg2576 (1)', 'Genotype'] = 'Tg2576'
dat['Genotype'].unique()
# Out:
# array(['APP/PS1', 'J20', 'Tg2576'], dtype=object)

# %%
no2576 = dat[dat['Genotype'].isin(['APP/PS1', 'J20'])]

# %%
def get_glm(region):
    formula = '%s ~ Genotype + APP + Sex' % region
    results = smf.ols(formula=formula, data=no2576).fit()
    
    return(results)

# %%
res = get_glm('SUBd')
anova = sm.stats.anova_lm(res, typ=2)
anova
# Out:
#                 sum_sq    df          F        PR(>F)
# Genotype  8.198988e+11   1.0  51.004501  2.509580e-08
# APP       1.300554e+12   1.0  80.905203  1.256932e-10
# Sex       1.962150e+11   1.0  12.206198  1.311395e-03
# Residual  5.626260e+11  35.0        NaN           NaN

# %%
res = get_glm('CA1')
anova = sm.stats.anova_lm(res, typ=2)
anova
# Out:
#                 sum_sq    df           F        PR(>F)
# Genotype  1.021082e+12   1.0   61.897381  3.009127e-09
# APP       1.751237e+12   1.0  106.158964  3.856390e-12
# Sex       2.413863e+11   1.0   14.632697  5.159134e-04
# Residual  5.773727e+11  35.0         NaN           NaN

# %%
res = get_glm('CA3')
anova = sm.stats.anova_lm(res, typ=2)
anova
# Out:
#                 sum_sq    df           F        PR(>F)
# Genotype  1.879504e+12   1.0   38.514015  4.137931e-07
# APP       5.438695e+12   1.0  111.447467  2.014897e-12
# Sex       5.822973e+11   1.0   11.932193  1.462385e-03
# Residual  1.708018e+12  35.0         NaN           NaN

# %%
res_dg = get_glm('DG')
anova_dg = sm.stats.anova_lm(res_dg, typ=2)
anova_dg
# Out:
#                 sum_sq    df           F        PR(>F)
# Genotype  2.471637e+12   1.0   43.689956  1.225210e-07
# APP       6.226094e+12   1.0  110.055710  2.384715e-12
# Sex       5.455437e+10   1.0    0.964332  3.328377e-01
# Residual  1.980027e+12  35.0         NaN           NaN

# %%
get_glm('DG').summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     DG   R-squared:                       0.811
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     50.13
# Date:                Mon, 30 Jul 2018   Prob (F-statistic):           9.33e-13
# Time:                        13:35:11   Log-Likelihood:                -536.02
# No. Observations:                  39   AIC:                             1080.
# Df Residuals:                      35   BIC:                             1087.
# Df Model:                           3
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept        9.955e+05   7.63e+04     13.056      0.000    8.41e+05    1.15e+06
# Genotype[T.J20]   5.04e+05   7.63e+04      6.610      0.000    3.49e+05    6.59e+05
# APP[T.-]        -7.999e+05   7.63e+04    -10.491      0.000   -9.55e+05   -6.45e+05
# Sex[T.M]        -7.488e+04   7.63e+04     -0.982      0.333    -2.3e+05    7.99e+04
# ==============================================================================
# Omnibus:                       23.509   Durbin-Watson:                   1.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):                3.558
# Skew:                           0.056   Prob(JB):                        0.169
# Kurtosis:                       1.524   Cond. No.                         3.74
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
dat.head()
# Out:
#   Genotype APP Sex    SUBd     CA1     CA3      DG       P
# 0  APP/PS1   -   F  477200  456283  790589  287563  724120
# 1  APP/PS1   -   F  539422  466490  629405  306358  726202
# 2  APP/PS1   -   F  546485  511429  625106  346131  761662
# 3  APP/PS1   -   F  505672  466640  613286  351195  692502
# 4  APP/PS1   -   F  510717  454516  560597  324772  666527

# %%
mdf = pd.melt(dat, id_vars = ['Genotype', 'APP', 'Sex'], var_name = 'Region', value_name = 'hAPP_level')

# %%
mdf.tail()
# Out:
#     Genotype APP Sex Region  hAPP_level
# 235   Tg2576   +   F      P     1714890
# 236   Tg2576   +   F      P     1342378
# 237   Tg2576   +   F      P     1292975
# 238   Tg2576   +   F      P     1339829
# 239   Tg2576   +   F      P     1189507

# %%
formula = 'hAPP_level ~ Genotype + APP + Sex + Region'
results = smf.ols(formula=formula, data=mdf).fit()
anova = sm.stats.anova_lm(results, typ=2)
anova
# Out:
#                 sum_sq     df           F        PR(>F)
# Genotype  7.220781e+12    3.0   58.308334  4.518752e-28
# APP       1.895807e+13    1.0  459.263497  9.822619e-57
# Sex       1.564863e+12    1.0   37.909147  3.270830e-09
# Region    7.546267e+12    4.0   45.702495  3.182893e-28
# Residual  9.494238e+12  230.0         NaN           NaN

# %%
meandat = dat.groupby(['Genotype', 'APP', 'Sex']).mean().reset_index()

# %%
meandat.to_csv(r'/Users/jenniferwh/Dropbox (Allen Institute)/Mesoscale Connectome Papers in Progress/2018 Plaque/hAPP immunostaining/hippocampal APP quantification means.csv')

# %%
mdf.head()
# Out:
#   Genotype APP Sex Region  hAPP_level
# 0  APP/PS1   -   F   SUBd      477200
# 1  APP/PS1   -   F   SUBd      539422
# 2  APP/PS1   -   F   SUBd      546485
# 3  APP/PS1   -   F   SUBd      505672
# 4  APP/PS1   -   F   SUBd      510717

# %%
path
# Out:
# '/Users/jenniferwh/Dropbox (Allen Institute)/Mesoscale Connectome Papers in Progress/2018 Plaque/hAPP immunostaining'

# %%
fig, ax = plt.subplots(1, 2, figsize = (14, 5))
h = sns.pointplot('Region', 'hAPP_level', hue = 'Sex', data = mdf[mdf['APP'] == '-'], ax = ax[0], legend = False,
                 palette = ['hotpink', 'cornflowerblue'])
g = sns.pointplot('Region', 'hAPP_level', hue = 'Sex', data = mdf[mdf['APP'] == '+'], ax = ax[1], legend = False,
                 palette = ['hotpink', 'cornflowerblue'])
g.legend(bbox_to_anchor = (1.1, 1))
h.legend_.remove()
h.set_title('APP (-) mice')
h.set_ylabel('hAPP Expression Level')
h.set_xlabel('')
g.set_title('APP (+) mice')
g.set_ylabel('hAPP Expression Level')
g.set_xlabel('')
plt.tight_layout()
plt.savefig(os.path.join(path, 'hAPP expression by sex in hippocampal regions.png'), 
            bbox_inches='tight', pad_inches=0.3, format='png', dpi=300)

# %%
mouse_line_colors = ['#8da0cb', '#fc8d62', '#66c2a5', '#000000']

# %%
mdf.loc[mdf['Genotype'] == 'Tg2576 (1)', 'Genotype'] = 'Tg2576'

# %%
fig, ax = plt.subplots(1, 2, figsize = (15, 5))
h = sns.pointplot('Region', 'hAPP_level', hue = 'Genotype', data = mdf[mdf['APP'] == '-'], ax = ax[0], legend = False,
                 palette = mouse_line_colors)
g = sns.pointplot('Region', 'hAPP_level', hue = 'Genotype', data = mdf[mdf['APP'] == '+'], ax = ax[1], legend = False,
                 palette = mouse_line_colors)
g.legend(bbox_to_anchor = (1.1, 1))
h.legend_.remove()
h.set_title('APP (-) mice')
h.set_ylabel('hAPP Expression Level')
h.set_xlabel('')
g.set_title('APP (+) mice')
g.set_ylabel('hAPP Expression Level')
g.set_xlabel('')
plt.tight_layout()
plt.savefig(os.path.join(path, 'hAPP expression by genotype in hippocampal regions.png'), 
            bbox_inches='tight', pad_inches=0.3, format='png', dpi=300)

# %%
fig, ax = plt.subplots(2, 2, figsize = (15, 10))
h = sns.pointplot('Region', 'hAPP_level', hue = 'Sex', data = mdf[mdf['APP'] == '-'], ax = ax[0, 0], legend = False,
                 palette = ['hotpink', 'cornflowerblue'])
g = sns.pointplot('Region', 'hAPP_level', hue = 'Sex', data = mdf[mdf['APP'] == '+'], ax = ax[0, 1], legend = False,
                 palette = ['hotpink', 'cornflowerblue'])
g.legend(bbox_to_anchor = (1.1, 1))
h.legend_.remove()
h.set_title('APP (-) mice')
h.set_ylabel('hAPP Expression Level')
h.set_xlabel('')
g.set_title('APP (+) mice')
g.set_ylabel('hAPP Expression Level')
g.set_xlabel('')
plt.tight_layout()
i = sns.pointplot('Region', 'hAPP_level', hue = 'Genotype', data = mdf[mdf['APP'] == '-'], ax = ax[1, 0], legend = False,
                 palette = mouse_line_colors)
j = sns.pointplot('Region', 'hAPP_level', hue = 'Genotype', data = mdf[mdf['APP'] == '+'], ax = ax[1, 1], legend = False,
                 palette = mouse_line_colors)
j.legend(bbox_to_anchor = (1.1, 1))
i.legend_.remove()
i.set_title('APP (-) mice')
i.set_ylabel('hAPP Expression Level')
i.set_xlabel('')
j.set_title('APP (+) mice')
j.set_ylabel('hAPP Expression Level')
j.set_xlabel('')
plt.tight_layout()
plt.savefig(os.path.join(path, 'hAPP expression by genotype and sex in hippocampal regions.png'), 
            bbox_inches='tight', pad_inches=0.3, format='png', dpi=300)

# %%
density = pd.read_csv(r'/Users/jenniferwh/Dropbox (Allen Institute)/Mesoscale Connectome Papers in Progress/2018 Plaque/hAPP immunostaining/mean APP and plaque density levels.csv')

# %%
density.drop(columns = {'APP'}, inplace = True)
density.head()
# Out:
#   Genotype Sex  hAPP_expression  plaque_density_same_region  \
# 0   Tg2576   F       1188253.60                    0.000126
# 1   Tg2576   F       1292807.25                    0.000212
# 2   Tg2576   F       1161396.20                    0.000147
# 3   Tg2576   F       1291579.75                    0.001091
# 4   Tg2576   F       1375915.80                    0.000000
#
#    relative_plaque_density_same_region  18_mo_plaque_density  \
# 0                             0.655883              0.001901
# 1                             1.101271              0.001901
# 2                             0.767727              0.005260
# 3                             5.681164              0.005260
# 4                             0.000000              0.001140
#
#    18_mo_relative_pd region  plaque_density_input_region  \
# 0           0.780735    CA1                     0.000147
# 1           0.780735    CA1                     0.001091
# 2           2.160267   SUBd                     0.000050
# 3           2.160267   SUBd                     0.000119
# 4           0.468346      P                     0.000058
#
#    relative_plaque_density_input_region input region  18_mo_plaque_density.1  \
# 0                              0.767727         SUBd                0.005260
# 1                              5.681164         SUBd                0.005260
# 2                              0.260333           DG                0.002165
# 3                              0.619853           DG                0.002165
# 4                              0.304069          CA3                0.000414
#
#    18_mo_relative_input_pd
# 0                 2.160267
# 1                 2.160267
# 2                 0.888970
# 3                 0.888970
# 4                 0.170029

# %%
h = sns.scatterplot('hAPP_expression', 'relative_plaque_density_same_region', hue = 'Genotype', data = density)
plt.legend(bbox_to_anchor = (1.1, 1))

# %%
h = sns.scatterplot('hAPP_expression', '18_mo_relative_pd', hue = 'Genotype', data = density)
plt.legend(bbox_to_anchor = (1.1, 1))

# %%
h = sns.scatterplot('hAPP_expression', 'relative_plaque_density_input_region', hue = 'Genotype', 
                    data = density)

# %%
h = sns.scatterplot('hAPP_expression', '18_mo_relative_input_pd', hue = 'Genotype', 
                    data = density)
plt.legend(bbox_to_anchor = (1.1, 1))

# %%
st.pearsonr(density['hAPP_expression'], density['relative_plaque_density_same_region'])
# Out:
# (0.035364570037792614, 0.8528157920688941)

# %%
st.pearsonr(density[density['Genotype'] == 'J20']['hAPP_expression'], 
            density[density['Genotype'] == 'J20']['plaque_density_same_region'])
# Out:
# (0.4640274783421803, 0.1767148300576636)

# %%
st.pearsonr(density['hAPP_expression'], density['relative_plaque_density_input_region'])
# Out:
# (-0.10815002471519593, 0.569448076992646)

# %%
st.pearsonr(density[density['Genotype'] == 'J20']['hAPP_expression'], 
            density[density['Genotype'] == 'J20']['plaque_density_input_region'])
# Out:
# (-0.2390490567265312, 0.5059515409927539)

# %%
st.pearsonr(density[(density['Genotype'] == 'Tg2576') &
                   (density['region'] != 'SUBd')]['hAPP_expression'], 
                                             density[(density['Genotype'] == 'Tg2576') &
                                                     (density['region'] != 'SUBd')][
                                                 '18_mo_relative_input_pd'])
# Out:
# (-0.0994377458428601, 0.8147796145840284)

# %%
st.pearsonr(density[density['Genotype'].isin(['J20'])]['hAPP_expression'], 
                                             density[density['Genotype'].isin(['J20'])][
                                                 'plaque_density_same_region'])
# Out:
# (0.4640274783421803, 0.1767148300576636)

# %%
st.pearsonr(density[(density['Genotype'] == 'J20') &
                   (density['region'] != 'SUBd')]['hAPP_expression'], 
                                             density[(density['Genotype'] == 'J20') &
                                                     (density['region'] != 'SUBd')][
                                                 'plaque_density_input_region'])
# Out:
# (-0.01044531652445088, 0.9804164560106161)

# %%
st.pearsonr(density['hAPP_expression'][density['Genotype'].isin(['APP/PS1'])], 
            density[density['Genotype'].isin(['APP/PS1'])]['plaque_density_same_region'])
# Out:
# (-0.2604398218812243, 0.4673835688556357)

# %%
st.pearsonr(density[(density['Genotype'] == 'APP/PS1') &
                   (density['region'] != 'SUBd')]['hAPP_expression'], 
            density[(density['Genotype'] == 'APP/PS1') &
                   (density['region'] != 'SUBd')]['plaque_density_input_region'])
# Out:
# (-0.39255284381923444, 0.3360821966360129)

# %%
st.pearsonr(density['hAPP_expression'], 
            density['plaque_density_input_region'].sample(frac = 1))
# Out:
# (0.03927020440819069, 0.8367663802898156)
